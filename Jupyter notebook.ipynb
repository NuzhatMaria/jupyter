# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# | Nuzhat maria Syeda|
# | ------ |
# | Data scientist |

# %% [markdown]
# *I am interested in data science because it has a promising career in the furture and it will give me a head start .*

# %% [markdown]
# ### I am going to add two number using addition sign

# %%
1+37
# Out:
# 38

# %% [markdown]
# This includes Table , highlights and bulleted list
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **nicely**
# 1 | 2 | 3
# ⋅⋅* work
# ⋅⋅* happiness
# ⋅⋅* peace
